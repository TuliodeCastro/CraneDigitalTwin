# %%
from dataset import build_risk_dataset
from train import train_model
from predict import predict_risk
from plots import plot_risk
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from dataset import build_risk_dataset
#       2 from train import train_model
#       3 from predict import predict_risk
#
# ImportError: cannot import name 'build_risk_dataset' from 'dataset' (c:\Users\tulio\Desktop\DigitalTwin_Projet\CraneDigitalTwin\risk_model\src\dataset.py)

# %%
df_risk = build_risk_dataset("../data/cfd")
df_risk.head()

# %%
model = train_model(df_risk)

# %%
df_original = pd.read_csv("../data/dataset_original.csv")
df_pred = predict_risk(model, df_original)

# %%
plot_risk(df_pred, "risk_pred", "Mapa de risco predito")
