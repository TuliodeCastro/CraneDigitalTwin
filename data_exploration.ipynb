# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "zones_combined_cleaned.csv"
df = pd.read_csv(path)

# %%
sns.heatmap(df.isna(), cbar=False)
plt.title("Mapa de valores ausentes")
plt.show()
